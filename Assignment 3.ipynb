# %% [markdown]
# # Task_3
# # Registeration_Id- DIRSS3146
# # Name- Harshal Raut

# %% [markdown]
# #Q1 Take any value from the user, print “odd” if the value entered is odd and print “even” otherwise.

# %%
#Q1

num = int(input("Enter a number: "))
if (num % 2) == 0:
   print("{0} is Even".format(num))
else:
   print("{0} is Odd".format(num))
# Out:
# Enter a number: 79
# 79 is Odd

# %% [markdown]
# #Q2 Take input from the user and check if the number is a complex number. a complex number is the sum of a real number and an imaginary number. For example: 5+2i

# %%
x=int(input("Enter 1 Numbers:"))
y=int(input("Enter 2 num:"))
a=int(input("Enter 3 num:"))
b=int(input("Enter 4 num:"))
d=x+a
z=y+b
print(f"Enter a number, sum is: {d}+i{z}")
# Out:
# Enter 1 Numbers:15
# Enter 2 num:20
# Enter 3 num:25
# Enter 4 num:37
# Enter a number, sum is: 40+i57

# %% [markdown]
# #Q3 Create a program to enter marks from the user out of 100 and display grades as per the following 90-100 (A), 75 to 90 (B), 60 to 75 (C), 45 to 60 (D), 33 to 45 (E) and remaining all are F.

# %%
x=int(input("Enter is number"))
if(x>90):
    print("A")
elif(x>75):
    print("B")
elif(x>60):
    print("C")
elif(x>45):
    print("D")
elif(x>33):
    print("E")
else:
    print("F")
# Out:
# Enter is number67
# C

# %% [markdown]
# #Q4 Say three integers have been given. Determine how many of them are equal to each other. Create a program to print 3 (if all 3 are same), 2 (if 2 are same) and 0 (if all numbers are different)

# %%
a=int(input("Enter 1 st num:"))
b=int(input("Enter 2 nd num:"))
c=int(input("Enter 3 rd num:"))
if (a==b==c):
    print(3)
elif(a==b or b==c or a==c):
    print(2)
else:
    print(0)
# Out:
# Enter 1 st num:20
# Enter 2 nd num:10
# Enter 3 rd num:20
# 2

# %% [markdown]
# #Q5 A truck runs a distance of N kms per day. Write a program to calculate how many days will be taken to cover M kms.

# %%
a=int(input("Enter the N kms per Day"))
b=int(input("Enter hoe distance cover(M kms)"))
print("Number of days to travel Distance",b/a)
# Out:
# Enter the N kms per Day100
# Enter hoe distance cover(M kms)500
# Number of days to travel Distance 5.0

# %% [markdown]
# #Q6 Pass your name, surname, phone_no, hobbies in a python script and get all the passed values in a line without space.

# %%
Name=str(input("Enter Name:"))
Surname=str(input("Enter surname:"))
phone_no=int(input("Enter Phone_no:"))
hobbie=str(input("Enter Hobbies:"))
print(Name,end='')
print(Surname,end='')
print(phone_no,end='')
print(hobbie,end='')
# Out:
# Enter Name:Harshal
# Enter surname:Raut
# Enter Phone_no:9405
# Enter Hobbies:Travelling
# HarshalRaut9405Travelling

# %% [markdown]
# #Q7 Write a python script to
# a. separate 2,3,6 characters from your ID.
# b. To print character 2 to 5 in your name and surname.
#
# c. Print all the characters of your name and surname

# %%
Id='123455698'
print(Id[2],Id[3],Id[6])
#ii>To print characters 2 to 5 in your name and surname
Name="Harshal"
Surname="Raut"
print(Name[2:5])
print(Surname[2:5])
#iii>print all the characters of your name and surname
print(Name + ""+Surname)
# Out:
# 3 4 6
# rsh
# ut
# HarshalRaut

# %% [markdown]
# #Q8 Write short introduction in a text file.Your Intro Consis of Name,Id,Contact number, Address,stream,joining_date,qualification,Hobbies,strength and weakness
# #Calculate Lines, Word,Characters

# %%
a=open("Info.txt",'r')
b=a.read()
a.close()

b
z=b.split()
m=len(z)
print("Words in text:",m)
l=0
with open("Info.txt",'r') as f:
    for line in f:
        l+=1
print("Lines in the txt",l) 
num=[]
for b in range(25):
    #print(list(z[b]))
    #print(b)
    e=len(z[b])
#     list(map(e:e+lenz[b]))
    num.append(e)
k=sum(num)
print("Characters in text:",k)
# Out:
# Words in text: 29
# Lines in the txt 10
# Characters in text: 179

# %% [markdown]
# #Q9 Create a function that performs division of numbers. Since divide by zero gives an infinite so if a number which is denominator and 0 must give an exception while performing division operation.

# %%
try:
    n=int(input())
    3/n
    print("Division Done")
   
    
except ZeroDivisionError:
        print("It is not divisible by 0")
# Out:
# 0
# It is not divisible by 0

# %% [markdown]
# #Q10 Create a file in read only mode. Open this file using python and try to write your contact number in that file. As this file is write protected so an exception should occur. Handle this exception using python script.

# %%
try:    
    a=open("contactdetailAS3.txt",'r')
    try:
        a.write("Contact_No:9405727")
    except:
        print("It couldn't Write")
        raise NameError
    

    finally:
        a.close()
except NameError:
    print("Not written")
# Out:
# It couldn't Write
# Not written

# %%
#Q11(a). Create an html generator using: A base class with a couple methods

# Base or super class. Note object in bracket.
# (Generally, object is made ancestor of all classes)
# In Python 3.x "class Person" is
# equivalent to "class Person(object)"
class Person(object):

    # Constructor
    def __init__(self, name):
       self.name = name

    # To get name
    def getName(self):
        return self.name

    # To check if this person is an employee
    def isEmployee(self):
        return False

# Inherited or Subclass (Note Person in bracket)
class Employee(Person):

    # Here we return true
    def isEmployee(self):
        return True

# Driver code
emp = Person("Regex1")
print(emp.getName(), emp.isEmployee())

emp = Employee("Regex2")
print(emp.getName(), emp.isEmployee())
# Out:
# Regex1 False
# Regex2 True

# %%
#Q11(b). Subclass overriding class attributes
# Write Python code here
class sampleclass:
    count = 0     # class attribute

    def increase(self):
        sampleclass.count += 1

# Calling increase() on an object

s1 = sampleclass()
s1.increase()

print(s1.count)

# Calling increase on one more
# object

s2 = sampleclass()
s2.increase()

print(s2.count)

print(sampleclass.count)
# Out:
# 1
# 2
# 2

# %%
#Q11(c). Subclass overriding a method
class Parent(object):
    def __init__(self):
        self.value = 5

    def get_value(self):
        return self.value

class Child(Parent):
    def get_value(self):
        return self.value + 1

# %%
#Q11(d) Subclass overriding the __init__
# defining a SuperClass
class SuperClass:

     # defining __init_subclass__method
     def __init_subclass__(cls, **kwargs):
         cls.default_name = "Inherited Class"
         
# defining a SubClass
class SubClass(SuperClass):

     # an attribute of SubClass
    default_name ="SubClass"
    print(default_name) 

subclass = SubClass()
print(subclass.default_name)
# Out:
# SubClass
# Inherited Class
